# %%
import requests, json
import threading
import pandas as pd
import flask
from flask import Flask, request
import geopy
from geopy import Nominatim

# %%
key = 'fsq3bR9nCSrR/WbzD82rlvh990Q70wuc8BuuRs0Ypm6fx+w='

# this method helps us get long and lat of certain city

def get_latlong(b):

    city = b

    geolocator = Nominatim(user_agent = 'Safra')

    loc = geolocator.geocode(city)

    return loc.latitude , loc.longitude

# %%
lat , long = get_latlong('riyadh')
lat , long
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\miniconda3\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\miniconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\miniconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\miniconda3\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File ~\miniconda3\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     conn = self._new_conn()
#     359     hostname = self.host
#
# File ~\miniconda3\lib\site-packages\urllib3\connection.py:179, in HTTPConnection._new_conn(self)
#     178 except SocketTimeout:
# --> 179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#     185 except SocketError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x0000014EB79D9B80>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~\miniconda3\lib\site-packages\urllib3\connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810     log.warning(
#     811         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     812     )
# --> 813     return self.urlopen(
#     814         method,
#     815         url,
#     816         body,
#     817         headers,
#     818         retries,
#     819         redirect,
#     820         assert_same_host,
#     821         timeout=timeout,
#     822         pool_timeout=pool_timeout,
#     823         release_conn=release_conn,
#     824         chunked=chunked,
#     825         body_pos=body_pos,
#     826         **response_kw
#     827     )
#     829 # Handle redirect?
#
# File ~\miniconda3\lib\site-packages\urllib3\connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810     log.warning(
#     811         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     812     )
# --> 813     return self.urlopen(
#     814         method,
#     815         url,
#     816         body,
#     817         headers,
#     818         retries,
#     819         redirect,
#     820         assert_same_host,
#     821         timeout=timeout,
#     822         pool_timeout=pool_timeout,
#     823         release_conn=release_conn,
#     824         chunked=chunked,
#     825         body_pos=body_pos,
#     826         **response_kw
#     827     )
#     829 # Handle redirect?
#
# File ~\miniconda3\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~\miniconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=egypt&format=json&limit=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000014EB79D9B80>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\geopy\adapters.py:448, in RequestsAdapter._request(self, url, timeout, headers)
#     447 try:
# --> 448     resp = self.session.get(url, timeout=timeout, headers=headers)
#     449 except Exception as error:
#
# File ~\miniconda3\lib\site-packages\requests\sessions.py:542, in Session.get(self, url, **kwargs)
#     541 kwargs.setdefault('allow_redirects', True)
# --> 542 return self.request('GET', url, **kwargs)
#
# File ~\miniconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\miniconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#
# File ~\miniconda3\lib\site-packages\requests\adapters.py:507, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     506     if not isinstance(e.reason, NewConnectionError):
# --> 507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=egypt&format=json&limit=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000014EB79D9B80>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 lat , long = get_latlong('egypt')
#       2 lat , long
#
# Input In [2], in get_latlong(b)
#       7 city = b
#       9 geolocator = Nominatim(user_agent = 'Safra')
# ---> 11 loc = geolocator.geocode(city)
#      13 return loc.latitude , loc.longitude
#
# File ~\miniconda3\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~\miniconda3\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File ~\miniconda3\lib\site-packages\geopy\adapters.py:438, in RequestsAdapter.get_json(self, url, timeout, headers)
#     437 def get_json(self, url, *, timeout, headers):
# --> 438     resp = self._request(url, timeout=timeout, headers=headers)
#     439     try:
#     440         return resp.json()
#
# File ~\miniconda3\lib\site-packages\geopy\adapters.py:460, in RequestsAdapter._request(self, url, timeout, headers)
#     458         raise GeocoderServiceError(message)
#     459     else:
# --> 460         raise GeocoderUnavailable(message)
#     461 elif isinstance(error, requests.Timeout):
#     462     raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=egypt&format=json&limit=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000014EB79D9B80>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))

# %%
def retrieve_places(a , c):

    """
    a : condition --- >  example : coffee , art gallery , etc ...
    c : city name
    
    """

    lat , long = get_latlong(c)


    if a != '':
        fields_url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&query={a}&fields=fsq_id%2Cname%2Ctel%2Cprice%2Crating%2Cdescription%2Clocation"

    else:
        fields_url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&fields=fsq_id%2Cname%2Ctel%2Cprice%2Crating%2Cdescription%2Clocation"


    url = fields_url

    headers = {
        "Accept": "application/json",
        "Authorization": key
    }

    response = requests.get(url, headers=headers)

    data = response.json()

    df = pd.json_normalize(data['results'])

    #deleting unnecessary columns
    
    df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)


    # renaming columns


    df.rename(columns = {'location.country':'country' , 'location.region':'region'}, inplace = True)

    

    # filling nan values

    df = df.fillna('Not Available')



    # changing datatypes
    df = df.astype({'price': str , 'rating': str})

    data = df.to_json(orient = 'records')
    return df , data

# %%
df, data_json = retrieve_places('' , 'Cairo')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df, data_json = retrieve_places('' , 'Cairo')
#       2 df
#
# NameError: name 'retrieve_places' is not defined

# %%
app = Flask(__name__)

@app.route('/api' , methods = ['GET'])

def index():
    userInputb = str(request.args['query'])
    df, data_json = retrieve_places('' , userInputb)

    return data_json




if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2022-09-24 20:15:45,828] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 13, in get_latlong
#     return loc.latitude , loc.longitude
# AttributeError: 'NoneType' object has no attribute 'latitude'
# 127.0.0.1 - - [24/Sep/2022 20:15:45] "GET /api?query= HTTP/1.1" 500 -
# [2022-09-24 20:15:47,956] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 13, in get_latlong
#     return loc.latitude , loc.longitude
# AttributeError: 'NoneType' object has no attribute 'latitude'
# 127.0.0.1 - - [24/Sep/2022 20:15:47] "GET /api?query= HTTP/1.1" 500 -
# [2022-09-24 20:15:50,253] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 13, in get_latlong
#     return loc.latitude , loc.longitude
# AttributeError: 'NoneType' object has no attribute 'latitude'
# 127.0.0.1 - - [24/Sep/2022 20:15:50] "GET /api?query= HTTP/1.1" 500 -
# [2022-09-24 20:15:51,728] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 13, in get_latlong
#     return loc.latitude , loc.longitude
# AttributeError: 'NoneType' object has no attribute 'latitude'
# 127.0.0.1 - - [24/Sep/2022 20:15:51] "GET /api?query= HTTP/1.1" 500 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# [2022-09-24 20:15:55,333] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 51, in retrieve_places
#     df = df.astype({'price': str , 'rating': str})
#   File "C:\Users\Saud\miniconda3\lib\site-packages\pandas\core\generic.py", line 5879, in astype
#     raise KeyError(
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'rating' not found in columns."
# 127.0.0.1 - - [24/Sep/2022 20:15:55] "GET /api?query=riy HTTP/1.1" 500 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:15:56] "GET /api?query=r HTTP/1.1" 200 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:15:56] "GET /api?query=ri HTTP/1.1" 200 -
# [2022-09-24 20:15:57,994] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\Saud\miniconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 785, in urlopen
#     retries = retries.increment(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riya&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 542, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riya&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 11, in get_latlong
#     loc = geolocator.geocode(city)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riya&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# 127.0.0.1 - - [24/Sep/2022 20:15:58] "GET /api?query=riya HTTP/1.1" 500 -
# [2022-09-24 20:15:58,211] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\Saud\miniconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 785, in urlopen
#     retries = retries.increment(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riyad&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 542, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riyad&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 11, in get_latlong
#     loc = geolocator.geocode(city)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riyad&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# 127.0.0.1 - - [24/Sep/2022 20:15:58] "GET /api?query=riyad HTTP/1.1" 500 -
# [2022-09-24 20:15:58,443] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\Saud\miniconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 785, in urlopen
#     retries = retries.increment(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 542, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 11, in get_latlong
#     loc = geolocator.geocode(city)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# 127.0.0.1 - - [24/Sep/2022 20:15:58] "GET /api?query=riyadh HTTP/1.1" 500 -
# [2022-09-24 20:16:07,725] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 13, in get_latlong
#     return loc.latitude , loc.longitude
# AttributeError: 'NoneType' object has no attribute 'latitude'
# 127.0.0.1 - - [24/Sep/2022 20:16:07] "GET /api?query= HTTP/1.1" 500 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# [2022-09-24 20:16:10,953] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 51, in retrieve_places
#     df = df.astype({'price': str , 'rating': str})
#   File "C:\Users\Saud\miniconda3\lib\site-packages\pandas\core\generic.py", line 5879, in astype
#     raise KeyError(
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'rating' not found in columns."
# 127.0.0.1 - - [24/Sep/2022 20:16:10] "GET /api?query=Riya HTTP/1.1" 500 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:16:11] "GET /api?query=R HTTP/1.1" 200 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:16:12] "GET /api?query=Ri HTTP/1.1" 200 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:16:12] "GET /api?query=Riyad HTTP/1.1" 200 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# [2022-09-24 20:16:14,776] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 51, in retrieve_places
#     df = df.astype({'price': str , 'rating': str})
#   File "C:\Users\Saud\miniconda3\lib\site-packages\pandas\core\generic.py", line 5879, in astype
#     raise KeyError(
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'rating' not found in columns."
# 127.0.0.1 - - [24/Sep/2022 20:16:14] "GET /api?query=Riy HTTP/1.1" 500 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:16:16] "GET /api?query=Riyadh HTTP/1.1" 200 -
# [2022-09-24 20:17:46,408] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 13, in get_latlong
#     return loc.latitude , loc.longitude
# AttributeError: 'NoneType' object has no attribute 'latitude'
# 127.0.0.1 - - [24/Sep/2022 20:17:46] "GET /api?query= HTTP/1.1" 500 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:17:49] "GET /api?query=r HTTP/1.1" 200 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:17:50] "GET /api?query=ri HTTP/1.1" 200 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# [2022-09-24 20:17:50,594] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 51, in retrieve_places
#     df = df.astype({'price': str , 'rating': str})
#   File "C:\Users\Saud\miniconda3\lib\site-packages\pandas\core\generic.py", line 5879, in astype
#     raise KeyError(
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'price' not found in columns."
# 127.0.0.1 - - [24/Sep/2022 20:17:50] "GET /api?query=riya HTTP/1.1" 500 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:17:51] "GET /api?query=riyad HTTP/1.1" 200 -
# [2022-09-24 20:17:52,449] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\Saud\miniconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 785, in urlopen
#     retries = retries.increment(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 542, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 11, in get_latlong
#     loc = geolocator.geocode(city)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# 127.0.0.1 - - [24/Sep/2022 20:17:52] "GET /api?query=riyadh HTTP/1.1" 500 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# [2022-09-24 20:17:53,192] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 51, in retrieve_places
#     df = df.astype({'price': str , 'rating': str})
#   File "C:\Users\Saud\miniconda3\lib\site-packages\pandas\core\generic.py", line 5879, in astype
#     raise KeyError(
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'rating' not found in columns."
# 127.0.0.1 - - [24/Sep/2022 20:17:53] "GET /api?query=riy HTTP/1.1" 500 -
# [2022-09-24 20:18:02,919] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 13, in get_latlong
#     return loc.latitude , loc.longitude
# AttributeError: 'NoneType' object has no attribute 'latitude'
# 127.0.0.1 - - [24/Sep/2022 20:18:02] "GET /api?query= HTTP/1.1" 500 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:18:06] "GET /api?query=R HTTP/1.1" 200 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# 127.0.0.1 - - [24/Sep/2022 20:18:06] "GET /api?query=Ri HTTP/1.1" 200 -
# C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py:34: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
# [2022-09-24 20:18:06,938] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 51, in retrieve_places
#     df = df.astype({'price': str , 'rating': str})
#   File "C:\Users\Saud\miniconda3\lib\site-packages\pandas\core\generic.py", line 5879, in astype
#     raise KeyError(
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'rating' not found in columns."
# 127.0.0.1 - - [24/Sep/2022 20:18:06] "GET /api?query=Riya HTTP/1.1" 500 -
# ...
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 542, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 11, in get_latlong
#     loc = geolocator.geocode(city)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# 127.0.0.1 - - [24/Sep/2022 21:41:53] "GET /api?query=Riyadh HTTP/1.1" 500 -
# [2022-09-24 21:41:53,705] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\Saud\miniconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 785, in urlopen
#     retries = retries.increment(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 542, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 11, in get_latlong
#     loc = geolocator.geocode(city)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# 127.0.0.1 - - [24/Sep/2022 21:41:53] "GET /api?query=Riyadh HTTP/1.1" 500 -
# [2022-09-24 21:41:53,829] ERROR in app: Exception on /api [GET]
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\Saud\miniconda3\lib\http\client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\Saud\miniconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\Saud\miniconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 813, in urlopen
#     return self.urlopen(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\connectionpool.py", line 785, in urlopen
#     retries = retries.increment(
#   File "C:\Users\Saud\miniconda3\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 448, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 542, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\requests\adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Saud\miniconda3\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3309281160.py", line 7, in index
#     df, data_json = retrieve_places('' , userInputb)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\3357617640.py", line 9, in retrieve_places
#     lat , long = get_latlong(c)
#   File "C:\Users\Saud\AppData\Local\Temp\ipykernel_24008\2767236446.py", line 11, in get_latlong
#     loc = geolocator.geocode(city)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\geocoders\base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 438, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\Saud\miniconda3\lib\site-packages\geopy\adapters.py", line 460, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Riyadh&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# 127.0.0.1 - - [24/Sep/2022 21:41:53] "GET /api?query=Riyadh HTTP/1.1" 500 -
