# %%
import requests , json
import threading
import pandas as pd
import flask
from flask import Flask
import geopy
from geopy import Nominatim

# %%
key = 'fsq3bR9nCSrR/WbzD82rlvh990Q70wuc8BuuRs0Ypm6fx+w='

# this method helps us get long and lat of certain city

def get_latlong(b):

    city = b

    geolocator = Nominatim(user_agent = 'Safra')

    loc = geolocator.geocode(city)

    return loc.latitude , loc.longitude

# %%
lat , long = get_latlong( 'Riyadh')

# %%
def retrieve_places(a , c):

    """
    a : condition --- >  example : coffee , art gallery , etc ...
    c : city name
    """

    lat , long = get_latlong(c)


    if a != '':
        fields_url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&query={a}&fields=fsq_id%2Cname%2Ctel%2Cprice%2Crating%2Cdescription%2Clocation"

    else:
        fields_url = f"https://api.foursquare.com/v3/places/search?ll={lat}%2C{long}&fields=fsq_id%2Cname%2Ctel%2Cprice%2Crating%2Cdescription%2Clocation"


    url = fields_url

    headers = {
        "Accept": "application/json",
        "Authorization": key
    }

    response = requests.get(url, headers=headers)

    data = response.json()

    df = pd.json_normalize(data['results'])

    #deleting unnecessary columns
    
    df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)


    # renaming columns


    df.rename(columns = {'location.country':'country' , 'location.region':'region'}, inplace = True)



    # filling nan values

    df = df.fillna('Not Available')



    # changing datatypes
    df = df.astype({'price': str , 'rating': str})

    data = df.to_json(orient = 'records')
    return df , data

# %%
df , data_json = retrieve_places('' , 'Riyadh')
df
# Out:
# C:\Users\Saud\AppData\Local\Temp\ipykernel_10424\2794973027.py:33: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['fsq_id', 'name', 'price', 'rating', 'tel', 'location.country', 'location.region', 'description']),1,inplace=True)
#                      fsq_id  \
# 0  50a21d4fe4b0225d6322ed03
# 1  5c8e4d17f709c1002ca94f02
# 2  4ee06435e5fa0be34659e3cf
# 3  5fca47490d6d9d74b579c8fa
# 4  566db885498e8b884eecff76
# 5  5e640a2684328a000895da0a
# 6  60703b211fee5e329ea0f64e
# 7  6248bb4a7da6a86c9bc265a5
# 8  544feecb498ef9028459c0f9
# 9  5dc3325ae167fe00084f61ce
#
#                                                 name rating            tel  \
# 0   King Abdulaziz Foundation (دارة الملك عبدالعزيز)    9.3   011 401 1999
# 1                               محامص ومطاحن السوادي    9.3  Not Available
# 2                               AlNaqaa (حمص النقاء)    9.4   011 206 4403
# 3  Masaha Misk Art Institute (قاعة مساحة معهد مسك...    9.5  Not Available
# 4                                Starbucks (ستاربكس)    9.4   011 511 1838
# 5                             COYARD Coffee Roasters    9.4  Not Available
# 6                                      Oakberry Açai    9.3  Not Available
# 7                                     Ba’a Bakehouse    9.4  Not Available
# 8                     Tamimi Markets (أسواق التميمي)    9.3  Not Available
# 9  Elixir Bunn Coffee Roasters (محمصة و مقهى إكسي...    9.3     9200 13926
#
#   country           region          price  \
# 0      SA  Riyadh Province  Not Available
# 1      SA  Riyadh Province            1.0
# 2      SA  Riyadh Province            1.0
# 3      SA  Riyadh Province  Not Available
# 4      SA  Riyadh Province            2.0
# 5      SA  Riyadh Province  Not Available
# 6      SA  Riyadh Province  Not Available
# 7      SA  Riyadh Province            1.0
# 8      SA  Riyadh Province  Not Available
# 9      SA  Riyadh Province            1.0
#
#                                          description
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4  The Starbucks Experience is more than a cup of...
# 5                                      Not Available
# 6                                      Not Available
# 7                                      Not Available
# 8                                      Not Available
# 9                                      Not Available

# %%
app = Flask(__name__)

@app.route('/' , methods = ['GET'])

def index():
    return data_json




if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
